# %% [markdown]
# ![image.png](http://www.sixthresearcher.com/wp-content/uploads/2016/12/Python3_reference_cheat_sheet_front.png)

# %% [markdown]
# ![image.png](https://core-electronics.com.au/media/wysiwyg/tutorials/clinton/A3_Python_Cheatsheet.png)
